# %% [markdown]
# ## Stock Market Analysis

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
# %matplotlib inline

# %%
start = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2017, 1, 1)

# %%
tesla = yf.download('TSLA', start, end)
ford = yf.download('F', start, end)
gm = yf.download('GM', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla.to_csv('Tesla_Stock.csv')
ford.to_csv('Ford_Stock.csv')
gm.to_csv('GM_Stock.csv')

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  15.935250   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.010946   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.783112  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.350874  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.290308  12084500

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.232306  45709900
# 2012-01-04  11.15  11.53  11.07  11.30   6.327499  79725200
# 2012-01-05  11.33  11.63  11.24  11.59   6.489886  67877500
# 2012-01-06  11.74  11.80  11.52  11.71   6.557082  59840700
# 2012-01-09  11.83  11.95  11.70  11.80   6.607475  53981500

# %% [markdown]
# #### Opening Prices

# %%
tesla['Open'].plot(label = 'Tesla', figsize = (15, 7))
gm['Open'].plot(label = 'GM')
ford['Open'].plot(label = 'Ford')
plt.ylabel('Stock Price')
plt.title('Stock Prices of Tesla, GM and Ford')
plt.legend()

# %%
tesla['Volume'].plot(label = 'Tesla', figsize = (15, 7))
gm['Volume'].plot(label = 'GM')
ford['Volume'].plot(label = 'Ford')
plt.ylabel('Volume Traded')
plt.legend()

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#              Open  High    Low  Close  Adj Close     Volume
# Date
# 2013-12-18  15.99  16.0  15.17  15.65    9.16414  220363000

# %%
ford.iloc[470:520]['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Market Cap

# %%
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded
# Date
# 2012-01-03  2.685921e+07
# 2012-01-04  1.777512e+07
# 2012-01-05  2.791269e+07
# 2012-01-06  2.682736e+07
# 2012-01-09  2.421900e+07

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  15.935250   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.010946   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.783112  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.350874  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.290308  12084500
#
#             Total Traded
# Date
# 2012-01-03  1.941627e+08
# 2012-01-04  1.653835e+08
# 2012-01-05  3.772807e+08
# 2012-01-06  4.059000e+08
# 2012-01-09  2.803604e+08

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  Total Traded
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.232306  45709900  5.028089e+08
# 2012-01-04  11.15  11.53  11.07  11.30   6.327499  79725200  8.889359e+08
# 2012-01-05  11.33  11.63  11.24  11.59   6.489886  67877500  7.690521e+08
# 2012-01-06  11.74  11.80  11.52  11.71   6.557082  59840700  7.025298e+08
# 2012-01-09  11.83  11.95  11.70  11.80   6.607475  53981500  6.386011e+08

# %%
tesla['Total Traded'].plot(label = 'Tesla', figsize = (15, 7))
gm['Total Traded'].plot(label = 'GM')
ford['Total Traded'].plot(label = 'Ford')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 538

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#                  Open       High    Low      Close  Adj Close     Volume  \
# Date
# 2014-02-25  15.333333  17.280001  15.23  16.533333  16.533333  490225500
#
#             Total Traded
# Date
# 2014-02-25  7.516791e+09

# %% [markdown]
# #### Moving Averages

# %%
gm['Open'].plot(label = 'No Moving Average', figsize = (15, 7))
gm['MA50'] = gm['Open'].rolling(50).mean()
gm['MA50'].plot(label = 'MA50')
gm['MA200'] = gm['Open'].rolling(200).mean()
gm['MA200'].plot(label = 'MA200')
plt.legend()

# %% [markdown]
# #### Correlation and Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_comp = pd.concat([tesla['Open'], gm['Open'], ford['Open']], axis = 1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Ford Open']

# %%
scatter_matrix(car_comp, figsize = (8, 8), hist_kwds = {'bins': 50})
# Out:
# array([[<Axes: xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <Axes: xlabel='GM Open', ylabel='Tesla Open'>,
#         <Axes: xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<Axes: xlabel='Tesla Open', ylabel='GM Open'>,
#         <Axes: xlabel='GM Open', ylabel='GM Open'>,
#         <Axes: xlabel='Ford Open', ylabel='GM Open'>],
#        [<Axes: xlabel='Tesla Open', ylabel='Ford Open'>,
#         <Axes: xlabel='GM Open', ylabel='Ford Open'>,
#         <Axes: xlabel='Ford Open', ylabel='Ford Open'>]], dtype=object)

# %% [markdown]
# ##### CandleStick Charts

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

ford_reset = ford.loc['2012-01':'2012-01'].reset_index()

ford_reset['date_ax'] = ford_reset['Date'].apply(lambda date: date2num(date))
ford_values = [tuple(vals) for vals in ford_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()
candlestick_ohlc(ax, ford_values, width = 0.6, colorup = 'g', colordown = 'r')
# Out:
# d:\Python\Lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+
# ([<matplotlib.lines.Line2D at 0x1ad53d52390>,
#   <matplotlib.lines.Line2D at 0x1ad53f6c890>,
#   <matplotlib.lines.Line2D at 0x1ad53f75790>,
#   <matplotlib.lines.Line2D at 0x1ad547662d0>,
#   <matplotlib.lines.Line2D at 0x1ad54767150>,
#   <matplotlib.lines.Line2D at 0x1ad54767fd0>,
#   <matplotlib.lines.Line2D at 0x1ad547651d0>,
#   <matplotlib.lines.Line2D at 0x1ad54766010>,
#   <matplotlib.lines.Line2D at 0x1ad5477eb90>,
#   <matplotlib.lines.Line2D at 0x1ad53e3fc10>,
#   <matplotlib.lines.Line2D at 0x1ad5478c710>,
#   <matplotlib.lines.Line2D at 0x1ad53ff95d0>,
#   <matplotlib.lines.Line2D at 0x1ad53f57050>,
#   <matplotlib.lines.Line2D at 0x1ad5478e450>,
#   <matplotlib.lines.Line2D at 0x1ad5478f290>,
#   <matplotlib.lines.Line2D at 0x1ad5478ffd0>,
#   <matplotlib.lines.Line2D at 0x1ad53fd5050>,
#   <matplotlib.lines.Line2D at 0x1ad5479dd90>,
#   <matplotlib.lines.Line2D at 0x1ad5479ec90>,
#   <matplotlib.lines.Line2D at 0x1ad54767d90>],
#  [<matplotlib.patches.Rectangle at 0x1ad4f30a2d0>,
#   <matplotlib.patches.Rectangle at 0x1ad53ffbf10>,
#   <matplotlib.patches.Rectangle at 0x1ad54765490>,
#   <matplotlib.patches.Rectangle at 0x1ad53fd6d50>,
#   <matplotlib.patches.Rectangle at 0x1ad54767090>,
#   <matplotlib.patches.Rectangle at 0x1ad54767f10>,
#   <matplotlib.patches.Rectangle at 0x1ad5477ced0>,
#   <matplotlib.patches.Rectangle at 0x1ad5477dd10>,
#   <matplotlib.patches.Rectangle at 0x1ad53f6f9d0>,
#   <matplotlib.patches.Rectangle at 0x1ad53f60910>,
#   <matplotlib.patches.Rectangle at 0x1ad53fc1950>,
#   <matplotlib.patches.Rectangle at 0x1ad5478d490>,
#   <matplotlib.patches.Rectangle at 0x1ad5474c110>,
#   <matplotlib.patches.Rectangle at 0x1ad5478e390>,
#   <matplotlib.patches.Rectangle at 0x1ad5478f1d0>,
#   <matplotlib.patches.Rectangle at 0x1ad5478ff90>,
#   <matplotlib.patches.Rectangle at 0x1ad5479cf90>,
#   <matplotlib.patches.Rectangle at 0x1ad5479dcd0>,
#   <matplotlib.patches.Rectangle at 0x1ad5479ebd0>,
#   <matplotlib.patches.Rectangle at 0x1ad53f7ad10>])

# %% [markdown]
# #### Daily Percentage Change

# %%
tesla['returns'] = (tesla['Close']/tesla['Close'].shift(1)) - 1
gm['returns'] = (gm['Close']/gm['Close'].shift(1)) - 1
ford['returns'] = (ford['Close']/ford['Close'].shift(1)) - 1

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded   returns
# Date
# 2012-01-03  2.685921e+07       NaN
# 2012-01-04  1.777512e+07 -0.013177
# 2012-01-05  2.791269e+07 -0.021292
# 2012-01-06  2.682736e+07 -0.007743
# 2012-01-09  2.421900e+07  0.012635

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  15.935250   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.010946   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.783112  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.350874  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.290308  12084500
#
#             Total Traded  MA50  MA200   returns
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  Total Traded  \
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.232306  45709900  5.028089e+08
# 2012-01-04  11.15  11.53  11.07  11.30   6.327499  79725200  8.889359e+08
# 2012-01-05  11.33  11.63  11.24  11.59   6.489886  67877500  7.690521e+08
# 2012-01-06  11.74  11.80  11.52  11.71   6.557082  59840700  7.025298e+08
# 2012-01-09  11.83  11.95  11.70  11.80   6.607475  53981500  6.386011e+08
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %% [markdown]
# #### Volatility

# %%
tesla['returns'].hist(bins = 100, label = 'Tesla', alpha = 0.5, figsize = (13, 6))
gm['returns'].hist(bins = 100, label = 'GM', alpha = 0.5)
ford['returns'].hist(bins = 100, label = 'Ford', alpha = 0.5)
plt.legend()

# %%
tesla['returns'].plot(kind = 'kde', label = 'Tesla', figsize = (15, 6))
gm['returns'].plot(kind = 'kde', label = 'GM')
ford['returns'].plot(kind = 'kde', label = 'Ford')
plt.legend()

# %% [markdown]
# #### Box Plots

# %%
box_df = pd.concat([tesla['returns'], gm['returns'], ford['returns']], axis = 1)
box_df.columns = ['Tesla Returns', 'GM Returns', 'Ford Returns']
box_df.plot(kind = 'box', figsize = (16, 6))
# Out:
# <Axes: >

# %%
scatter_matrix(box_df, figsize = (8, 8), hist_kwds = {'bins':50}, alpha = 0.25)
# Out:
# array([[<Axes: xlabel='Tesla Returns', ylabel='Tesla Returns'>,
#         <Axes: xlabel='GM Returns', ylabel='Tesla Returns'>,
#         <Axes: xlabel='Ford Returns', ylabel='Tesla Returns'>],
#        [<Axes: xlabel='Tesla Returns', ylabel='GM Returns'>,
#         <Axes: xlabel='GM Returns', ylabel='GM Returns'>,
#         <Axes: xlabel='Ford Returns', ylabel='GM Returns'>],
#        [<Axes: xlabel='Tesla Returns', ylabel='Ford Returns'>,
#         <Axes: xlabel='GM Returns', ylabel='Ford Returns'>,
#         <Axes: xlabel='Ford Returns', ylabel='Ford Returns'>]],
#       dtype=object)

# %% [markdown]
# #### Cumulative Return

# %%
tesla['Cumulative Return'] = (1 + tesla['returns']).cumprod()
gm['Cumulative Return'] = (1 + gm['returns']).cumprod()
ford['Cumulative Return'] = (1 + ford['returns']).cumprod()

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded   returns  Cumulative Return
# Date
# 2012-01-03  2.685921e+07       NaN                NaN
# 2012-01-04  1.777512e+07 -0.013177           0.986823
# 2012-01-05  2.791269e+07 -0.021292           0.965812
# 2012-01-06  2.682736e+07 -0.007743           0.958333
# 2012-01-09  2.421900e+07  0.012635           0.970442

# %%
tesla['Cumulative Return'].plot(label = 'Tesla', figsize = (15, 7))
ford['Cumulative Return'].plot(label = 'Ford')
gm['Cumulative Return'].plot(label = 'GM')
plt.legend()
